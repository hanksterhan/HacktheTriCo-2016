# %%
import pandas as pd
import matplotlib.pyplot as plt

""" Columns:Year,Player,Pos,Age,Tm,G,GS,MP,PER,TS%
            3PAr,FTr,ORB%,DRB%,TRB%,AST%,STL%,BLK%
            TOV%,USG%,blanl,OWS,DWS,WS,WS/48,blank2
            OBPM,DBPM,BPM,VORP,FG,FGA,FG%,3P,3PA,3P%
            2P,2PA,2P%,eFG%,FT,FTA,FT%,ORB,DRB,TRB,AST
            STL,BLK,TOV,PF,PTS
"""

df = pd.read_csv('Seasons_Stats.csv')

kyrie = df.loc[df['Player'] == 'Kyrie Irving']
kyrie = kyrie.set_index([[2012, 2013, 2014, 2015, 2016, 2017]])
del kyrie['Unnamed: 0'], kyrie['Pos'], kyrie['Age'], kyrie['Tm']

kyrie.head()
# Out:
#         Year        Player     G    GS      MP   PER    TS%   3PAr    FTr  \
# 2012  2012.0  Kyrie Irving  51.0  51.0  1558.0  21.4  0.566  0.245  0.262
# 2013  2013.0  Kyrie Irving  59.0  59.0  2048.0  21.4  0.553  0.261  0.271
# 2014  2014.0  Kyrie Irving  71.0  71.0  2496.0  20.1  0.533  0.278  0.273
# 2015  2015.0  Kyrie Irving  75.0  75.0  2730.0  21.5  0.583  0.306  0.296
# 2016  2016.0  Kyrie Irving  53.0  53.0  1667.0  19.9  0.540  0.298  0.217
#
#       ORB%   ...      FT%   ORB    DRB    TRB    AST    STL   BLK    TOV  \
# 2012   3.1   ...    0.872  44.0  147.0  191.0  275.0   54.0  20.0  160.0
# 2013   1.8   ...    0.855  34.0  182.0  216.0  350.0   89.0  21.0  191.0
# 2014   2.3   ...    0.861  52.0  207.0  259.0  433.0  108.0  23.0  190.0
# 2015   2.3   ...    0.863  55.0  182.0  237.0  389.0  114.0  20.0  186.0
# 2016   3.0   ...    0.885  44.0  113.0  157.0  249.0   56.0  18.0  124.0
#
#          PF     PTS
# 2012  110.0   944.0
# 2013  146.0  1325.0
# ...

# %%
FT = kyrie['FT%']
TS = kyrie['TS%']
years = kyrie['Year']
plt.scatter(FT, TS, cmap=kyrie['Year'])
plt.ticklabel_format(useOffset=False)
i = 0
for x,y in zip(FT,TS):
    year = years.iloc[i]            
    plt.annotate(s = year, xy = (x,y))
    i += 1
# plt.axis([2011,2018,0.84,0.92])
plt.title('Kyrie Irving FT%')
plt.xlabel('FT%')
plt.ylabel('TS%')
plt.margins(0.10)
plt.show()
